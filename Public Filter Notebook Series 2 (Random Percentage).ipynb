# %%
import numpy as np
import pandas as pd #Imports used 
import string

# %%
data = 'C:/Users/Alin/Desktop/pokemon.csv'  ##Input name of the File location and csv file here
df = pd.read_csv(data)

# %%
df.head() ###check data source uploaded
# Out:
#     TYPE   type2  weight_kg  generation  is_legendary        name  \
# 0  grass  poison        6.9           1             0   Bulbasaur
# 1  grass  poison       13.0           1             0     Ivysaur
# 2  grass  poison      100.0           1             0    Venusaur
# 3   fire     NaN        8.5           1             0  Charmander
# 4   fire     NaN       19.0           1             0  Charmeleon
#
#       japanese_name                    abilities  against_bug  against_dark  \
# 0  Fushigidaneフシギダネ  ['Overgrow', 'Chlorophyll']          1.0           1.0
# 1   Fushigisouフシギソウ  ['Overgrow', 'Chlorophyll']          1.0           1.0
# 2  Fushigibanaフシギバナ  ['Overgrow', 'Chlorophyll']          1.0           1.0
# 3      Hitokageヒトカゲ     ['Blaze', 'Solar Power']          0.5           1.0
# 4       Lizardoリザード     ['Blaze', 'Solar Power']          0.5           1.0
#
#    ...  experience_growth  height_m  hp   japanese_name.1      name.1  \
# ...

# %%
df.shape  ###Use to verify rows and colums
# Out:
# (801, 43)

# %%
with pd.option_context('display.max_rows', 30000):
    display(df)    ####Not always needed but can be used to check data source##

# %%
df['TYPE'].unique()  ###Use to check values indesired Column
# Out:
# array(['grass', 'fire', 'water', 'bug', 'normal', 'poison', 'electric',
#        'ground', 'fairy', 'fighting', 'psychic', 'rock', 'ghost', 'ice',
#        'dragon', 'dark', 'steel', 'flying'], dtype=object)

# %%
df.dropna(subset=['TYPE'], inplace=True)
#Remove nulls from desired column

# %%
df_unique = df.drop_duplicates('name')  ###remove potential duplicates from second filter field based on desire

# %%
df_unique.groupby(['TYPE']).agg({'TYPE' : 'count'})
# Out:
#           TYPE
# TYPE
# bug         72
# dark        29
# dragon      27
# electric    39
# fairy       18
# fighting    28
# fire        52
# flying       3
# ghost       27
# grass       78
# ground      32
# ice         23
# normal     105
# poison      32
# psychic     53
# rock        45
# steel       24
# water      114

# %%
df_unique_final = df_unique.groupby('TYPE', group_keys = False).apply(lambda x : x.sample(int(len(x)*0.15))).reset_index(drop=True)

# %%
####In cell above this will filter your csv file by any percent chosen. Simply replace the  "0.15" to
##your desired percent. Currently this will give you a random sample of 15 percent

# %%
df_unique_final.groupby(['TYPE']).agg({'TYPE' : 'count'}) ###Verify success by viweing new readouts
# Out:
#           TYPE
# TYPE
# bug         10
# dark         4
# dragon       4
# electric     5
# fairy        2
# fighting     4
# fire         7
# ghost        4
# grass       11
# ground       4
# ice          3
# normal      15
# poison       4
# psychic      7
# rock         6
# steel        3
# water       17

# %%
df_unique_final.to_csv ('Demo.csv', index = False, header=True)

# %%
###Write to a path and name the csv file

#I hope this helps someones project. Enjoy!!!
